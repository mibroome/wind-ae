# %%
import subprocess
import wrapper.six_plot as six
import McAstro.atoms as McAtom

# %%
sim = wind_sim()
sim.load_planet('saves/james_high_flux_full.csv',expedite=False)
vars1 = sim.windsoln
# Out:
# Atmosphere Composition
#   Species:   HI
#   Mass frac: 1.00e+00
# 7.549159851063774e-13
# Atmosphere Composition
#   Species:   HI
#   Mass frac: 1.00e+00

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# --------------------------------------------------------------------------------------0
# ![image-2.png](attachment:image-2.png)
# ![image-5.png](attachment:image-5.png)

# %%
rho   = vars1.soln['rho']
v     = vars1.soln['v']
r     = vars1.soln_norm['r'] #or soln
T     = vars1.soln['T']
gamma = 5/3
mu    = 
ion_pot = vars1.ion_pot
n_0   = vars1.soln['n_HI']
E = vars1.sim_spectrum['E']
nu = E/const.h
nu_0 = nu[idx]
sigma = vars1.sim_spectrum['sigma_HI'][nu==nu_0]
F = vars1.Fuv*(E*vars1.sim_spectrum['wPhi'])[nu==nu_0]
tau = vars1.soln['Ncol_HI']*sigma
epsilon = (E - ion_pot)/E 
Gamma = epsilon * F * np.exp(-tau) *sigma * n_0
Lambda =

# %%
fig, ax = plt.subplots(figsize=[8,6])
energy_plot(vars1, ax, all_terms=True)
ax.set_xlim((0.9,3.8))
ax.set_ylim((1e-12,1e-4))
E = vars1.sim_spectrum['E']/const.eV
ax.set_title('Solar Spectrum (%.1f - %.1f eV)' %(np.min(E),np.max(E)))
fig.tight_layout()
plt.savefig('../Figures/James_unconverged_high_energy',dpi=300,facecolor='white')
